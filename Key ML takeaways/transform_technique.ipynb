# %% [markdown]
# # Use of .fit , .fit_transform , .predict

# %% [markdown]
# z=x−μ/σ

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ```python
# scaler = StandardScaler()
# X_train_scaled = scaler.fit_transform(X_train)
# X_test_scaled = scaler.transform(X_test)
# ```
# # In TRANSFORMERS
# # in scaler.fit() this only calculates mean and std dev but not apply on the data
# # here what basically happen is that scaler.fit_transform(X_train) --> calculates the mean and std dev and then fit's it means calculates z1 for x1 and so on using above formula and standadize the data with mean = 0 and std dev = 1
# # but scaler.transform directly uses the mean and std dev and transforms that data without calculating it again means z1 for x1 and so on

# %% [markdown]
# # .fit() ----> we calculate what is needed
# # .transform ----> to apply calculated parameters on the data
# # .fit_transform ----> to calculate as well as apply on the data

# %% [markdown]
# # In models
# ### In model.fit() ----> it learns parameters and weights
# ### In model.predict(x_test_scaled) ----> here it predict the values

# %% [markdown]
# | Data Type| Transformer   | Model |
# |----------|:-------------:|------:|
# | Train data | .fit_transform() | .fit() |
# | Test data |  .transform()   |  .predict |
